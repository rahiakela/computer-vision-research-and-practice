# %% [markdown]
# <a href="https://colab.research.google.com/github/rahiakela/computer-vision-research-and-practice/blob/main/opencv-projects-and-guide/ocr-with-opencv-and-tesseract/01_first_ocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##First OCR with Tesseract

# %%
# %%shell
#
# sudo apt install tesseract-ocr
# pip install tesseract
# pip install pytesseract
# pip install Pillow==9.0.0

# %% [markdown]
# Just restart the colab environment.

# %%
import cv2
import pytesseract
import csv

from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %matplotlib inline

# %%
pytesseract.pytesseract.tesseract_cmd = (r'/usr/bin/tesseract')

# %% [markdown]
# Let's download images.

# %%
# %%shell
#
# wget https://github.com/rahiakela/computer-vision-research-and-practice/raw/main/opencv-projects-and-guide/ocr-with-opencv-and-tesseract/images/ocr.png
# wget https://github.com/rahiakela/computer-vision-research-and-practice/raw/main/opencv-projects-and-guide/ocr-with-opencv-and-tesseract/images/steve_jobs.png
# wget https://github.com/rahiakela/computer-vision-research-and-practice/raw/main/opencv-projects-and-guide/ocr-with-opencv-and-tesseract/images/whole_foods.png

# %% [markdown]
# Let's define some function.

# %%
def show_image(img_path):
  # load the input image and convert it from BGR to RGB channel ordering
  image = cv2.imread(img_path)
  plt.imshow(image)

def extract_text(img_path):
  image = cv2.imread(img_path)

  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

  # use Tesseract to OCR the image
  text = pytesseract.image_to_string(image)
  return text

# %%
show_image("ocr.png")

# %%
print(extract_text("ocr.png"))
# Out:
# PyImageSearch
# PO Box 17598 #17900
# Baltimore, MD 21297

# %%
show_image("steve_jobs.png")

# %%
print(extract_text("steve_jobs.png"))
# Out:
# Steven P. Jobs
# Chairman of the Board
#
# Apple Computer, Inc.
#
# 20525 Mariani Avenue, MS; 3K
# Cupertino, California 95014
# 408 973-2121 or 996-1010

# %% [markdown]
# Now, let’s apply to a more challenging photo of a Whole Food’s receipt.

# %%
show_image("whole_foods.png")

# %%
print(extract_text("whole_foods.png"))
# Out:
# HOLE FOODS HARKET VESTPORT, CT 06880
#
# 3g9 post RD WEST (203) 227-6888
#
# Bacon LS NP
# acon LS NP
#
# 368
#
# 365
# 366 BACON LS ne
# 366 BACON LS NP
# roth CHIC NP
# FLOUR, ALMONDANP
#
# 4.99 F
# 4.99 F
# 4.99 F
# 4.99 F
